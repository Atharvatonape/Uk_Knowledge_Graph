# %% [markdown]
# # Rule-Based Matching for NER

# %% [markdown]
# ## #1. Setup development environment

# %% [markdown]
# ###Update & import Python modules

# %%
# install and download spaCy related modules
# !pip install --upgrade spacy
# !python -m spacy download en_core_web_lg

# spaCy
import spacy
from spacy.language import Language
from spacy.tokens import Span
from spacy.matcher import PhraseMatcher

# Google Drive
from google.colab import drive

# Firebase/Firestore
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# general Python modules
import json
from datetime import datetime
from pprint import pprint
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.1/en_core_web_lg-3.4.1-py3-none-any.whl (587.7 MB)
#      |████████████████████████████████| 587.7 MB 17 kB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-lg==3.4.1) (3.4.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.10.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (8.1.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (57.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.9.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2022.9.24)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %% [markdown]
# ### Get access to Firebase and Drive

# %%
# remount drive, forced if needed
drive.mount("/content/gdrive/", force_remount = True)
print("Stablished access to Google Drive")

# initialize Drive path
DRIVE_PATH = "/content/gdrive/My Drive"

# open Firebase credentials
with open(DRIVE_PATH + "/ie_course/credentials/firebase_credentials.json") as f:
  credential = json.load(f)
credential = credentials.Certificate(credential)

# create Firestore database instance
firebase_admin.initialize_app(credential)
db = firestore.client()
print("Stablished access to Firestore")
# Out:
# Mounted at /content/gdrive/
# Stablished access to Google Drive
# Stablished access to Firestore

# %% [markdown]
# ### Retrieve main data structures

# %%
# retrieve Text Record from JSON file
with open(DRIVE_PATH + "/ie_course/retrieved_data/text_record.json") as f:
  text_rec = json.load(f)
  print(f"Retrieved text record")

# retrieve list of entities gazetteers
with open(DRIVE_PATH + "/ie_course/assets/entities_gazetteers.json") as f:
  entities_gazetteers_list = json.load(f)
  print(f"Retrieved entities gazetteers list")

# retrieve ignore list of entities gazetteers
with open(DRIVE_PATH + "/ie_course/assets/entities_gazetteers_ignore_list.json") as f:
  entities_gazetteers_ignore_list = json.load(f)
  print(f"Retrieved entities gazetteers' ignore list")

# retrieve entities
with open(DRIVE_PATH + "/ie_course/assets/entities.json") as f:
  entities = json.load(f)
  print(f"Retrieved entities")
# Out:
# Retrieved text record
# Retrieved entities gazetteers list
# Retrieved entities gazetteers' ignore list
# Retrieved entities

# %% [markdown]
# ## #2. Create custom pipeline

# %% [markdown]
# ### Create custom pipeline component

# %%
""" Custom pipeline Component: entities gazetteer function """

@Language.component("entities_gazetteer")
def entities_gazetteer(doc):
  # set up and extend structure of default span object
  span = Span(doc, 0, 0, "")
  span.set_extension("qid", default=None, force=True)
  span.set_extension("label", default=None, force=True)
  span.set_extension("wd_name", default=None, force=True)

  # identify matches of the gazetteers contained in Doc object (text)
  matches = matcher(doc)
  # convert matches to Span objects
  spans = [doc[start:end] for _, start, end in matches]
  # filter overlaping matches (Span objs) to keep gazetteers uniqueness
  filtered_matches = spacy.util.filter_spans(spans)

  # loop unique matches of gazetteers
  for match in filtered_matches:
    # skip if matched gazetter is in ignore list
    if match.text in entities_gazetteers_ignore_list:
      print(f"-- Skipped '{match}' due it's in ignore list!")
      continue
    # find matched gazetters in issues dictionary to get entities' Wikidata info
    # usually only one entity is found, but some gazetteer finds more than one
    matched_entities = [i for i in entities if match.text == i["name"] or match.text in i["aliases"]]
    if len(matched_entities):
      entity = Span(doc, match.start, match.end, label=matched_entities[0]["label"])

      # set attributes
      if len(matched_entities) == 1:
        entity._.label = matched_entities[0]["label"]
      elif len(matched_entities) > 1:
        entity._.label = [e["label"] for e in matched_entities]

      entity.set_extension("qid", default=None, force=True)
      if len(matched_entities) == 1:
        entity._.qid = matched_entities[0]["qid"]
      elif len(matched_entities) > 1:
        entity._.qid = [e["qid"] for e in matched_entities]

      entity.set_extension("wd_name", default=None, force=True)
      if len(matched_entities) == 1:
        entity._.wd_name = matched_entities[0]["name"]
      elif len(matched_entities) > 1:
        entity._.wd_name = [e["name"] for e in matched_entities]

      # modify the provided entity spans, leaving the rest unmodified
      doc.set_ents([entity], default="unmodified")

  return doc

# create pipeline loaded with a pretrained statistical model (English/lg)
nlp = spacy.load("en_core_web_lg", exclude=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])
nlp.add_pipe("sentencizer")

# add custom component to pipeline
nlp.add_pipe("entities_gazetteer", last=True)

# initialize spaCY phrase matcher (rule-based)
matcher = PhraseMatcher(nlp.vocab, None)

# load gazetteers (issues) as matcher patterns
patterns = [nlp.make_doc(gazetteer) for gazetteer in entities_gazetteers_list]
matcher.add("gazetteers", patterns)

# see pipeline components
print(nlp.pipe_names)

# analize pipeline
pprint(nlp.analyze_pipes(pretty=True))
# Out:
# ['ner', 'sentencizer', 'entities_gazetteer']
#
# ============================= Pipeline Overview =============================
#
# #   Component            Assigns               Requires   Scores          Retokenizes
# -   ------------------   -------------------   --------   -------------   -----------
# 0   ner                  doc.ents                         ents_f          False
#                          token.ent_iob                    ents_p
#                          token.ent_type                   ents_r
#                                                           ents_per_type
#
# 1   sentencizer          token.is_sent_start              sents_f         False
#                          doc.sents                        sents_p
#                                                           sents_r
#
# 2   entities_gazetteer                                                    False
#
# ✔ No problems found.
# {'attrs': {'doc.ents': {'assigns': ['ner'], 'requires': []},
#            'doc.sents': {'assigns': ['sentencizer'], 'requires': []},
#            'token.ent_iob': {'assigns': ['ner'], 'requires': []},
#            'token.ent_type': {'assigns': ['ner'], 'requires': []},
#            'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []}},
#  'problems': {'entities_gazetteer': [], 'ner': [], 'sentencizer': []},
#  'summary': {'entities_gazetteer': {'assigns': [],
#                                     'requires': [],
#                                     'retokenizes': False,
#                                     'scores': []},
#              'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#                      'requires': [],
#                      'retokenizes': False,
#                      'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type']},
#              'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#                              'requires': [],
#                              'retokenizes': False,
#                              'scores': ['sents_f', 'sents_p', 'sents_r']}}}

# %% [markdown]
# ## #3. Extract Named-Entities from text

# %% [markdown]
# ### Process text for NER

# %%
# initialize main container of text
main_text_container = []
# main_text_woc_container = []
text = text_rec["texts"]

# split text in paragraphs
for index, paragraph in enumerate(text):
  # split paragraph in sentences
  sentences = [sent.text for sent in nlp(paragraph).sents]

  # process sentences individually in a stream (multi-thread)
  for doc in nlp.pipe(sentences, batch_size=50):
    sent = doc.text  # sentence
    chosen_sentence = [sent, {"entities": []}]
    for ent in doc.ents:
      if ent._.qid:
        chosen_sentence[1]["entities"].append([ent.start_char, ent.end_char, ent._.qid, ent.text, ent.label_, ent._.label, ent._.wd_name])
    if len(chosen_sentence[1]["entities"]):
      main_text_container.append(chosen_sentence)
      print()
      print(f"++ {sent}")
      for ent in doc.ents:
        if ent._.qid:
          print(f"    {ent.text, ent.start_char, ent.end_char, ent.label_, ent._.label, ent._.qid, ent._.wd_name}")
      print()

# save record in JSON file
if len(main_text_container):
  with open(DRIVE_PATH + "/ie_course/output/extracted_sentences.json", "w", encoding = "utf-8") as f:
    json.dump(main_text_container, f, ensure_ascii = False, indent = 2)
    print()
    print(f"Saved {len(main_text_container)} extracted_sentences")
# Out:
# ++ Florida became more flame-like, but it’s going to be under control.
#     ('Florida', 0, 7, 'GPE', 'GPE', 'Q812', 'Florida')
#
#
# ++ They don’t talk about Mexico, Mexico and Brazil and still parts of Europe, which actually got hit sooner than us, so it’s a little ahead of us in that sense.
#     ('Mexico', 22, 28, 'GPE', 'GPE', 'Q96', 'Mexico')
#     ('Mexico', 30, 36, 'GPE', 'GPE', 'Q96', 'Mexico')
#     ('Brazil', 41, 47, 'GPE', 'GPE', 'Q155', 'Brazil')
#
#
# ++ But you take a look, why don’t they talk about Mexico, which is not helping us?
#     ('Mexico', 47, 53, 'GPE', 'GPE', 'Q96', 'Mexico')
#
#
# ++ And all I can say is thank God I built most of the wall because if I didn’t have the wall up we would have a much bigger problem with Mexico.
#     ('Mexico', 134, 140, 'GPE', 'GPE', 'Q96', 'Mexico')
#
# -- Skipped 'right' due it's in ignore list!
# -- Skipped 'right' due it's in ignore list!
# -- Skipped 'right' due it's in ignore list!
#
# ++ Look, I take responsibility always for everything because it’s ultimately my job to.
#     ('job', 77, 80, 'CONCEPT', 'CONCEPT', 'Q192581', 'job')
#
# -- Skipped 'right' due it's in ignore list!
#
# ++ They call and they say the most incredible job anybody’s done is our job on testing, because we’re going to very shortly be up to 50 million tests.
#     ('job', 43, 46, 'CONCEPT', 'CONCEPT', 'Q192581', 'job')
#     ('job', 69, 72, 'CONCEPT', 'CONCEPT', 'Q192581', 'job')
#
#
# ++ It came from China, they should have never let it escape, they should have never let it out.
#     ('China', 13, 18, 'GPE', 'GPE', 'Q148', "People's Republic of China")
#
# -- Skipped 'program' due it's in ignore list!
# -- Skipped 'program' due it's in ignore list!
#
# ++ They basically did whatever China wanted them to.
#     ('China', 28, 33, 'GPE', 'GPE', 'Q148', "People's Republic of China")
#
#
# ++ Dr. Fauci told me not to ban China, it would be a big mistake.
#     ('China', 29, 34, 'GPE', 'GPE', 'Q148', "People's Republic of China")
#
# -- Skipped 'right' due it's in ignore list!
#
# ++ Dr. Fauci said, “Don’t ban China.
#     ('China', 27, 32, 'GPE', 'GPE', 'Q148', "People's Republic of China")
#
#
# ++ Don’t ban China.”
#     ('China', 10, 15, 'GPE', 'GPE', 'Q148', "People's Republic of China")
#
# -- Skipped 'right' due it's in ignore list!
#
# ++ The state of New Jersey had thousands of deaths.
#     ('New Jersey', 13, 23, 'GPE', 'GPE', 'Q1408', 'New Jersey')
#
#
# ++ One person below the age of 18 died in the state of New Jersey during all of this.
#     ('New Jersey', 52, 62, 'GPE', 'GPE', 'Q1408', 'New Jersey')
#
#
# ++ Look, the Democrats don’t want to do that because they’re totally captured by the lobby of lawyers.
#     ('the Democrats', 6, 19, 'NORP', 'NORP', 'Q29552', 'Democratic Party')
#
#
# ++ I explain it very simply by saying, their Democrat run cities, they’re liberally run.
#     ('Democrat', 42, 50, 'NORP', 'NORP', 'Q29552', 'Democratic Party')
#
#
# ++ We have a forced them in Seattle to end the chop because we were going in that following day.
#     ('Seattle', 25, 32, 'GPE', 'GPE', 'Q5083', 'Seattle')
#
#
# ++ And when they heard that we were going, they set their police force.
#     ('police force', 55, 67, 'ORG', 'ORG', 'Q35535', 'police')
#
#
# ++ Meanwhile, the George Floyd murder has re-ignited the issue of racism in policing in this country.
#     ('racism', 63, 69, 'CONCEPT', 'CONCEPT', 'Q3308225', 'ethnic hatred')
#
#
# ++ In Minneapolis over the last five years, police use force against blacks at a rate seven times that against whites.
#     ('Minneapolis', 3, 14, 'GPE', 'GPE', 'Q36091', 'Minneapolis')
#
# -- Skipped 'right' due it's in ignore list!
#
# ++ If you look at what’s going on in Portland, those are anarchists and we’ve taken a very tough stand.
#     ('Portland', 34, 42, 'GPE', 'GPE', 'Q6106', 'Portland')
#
#
# ++ If we didn’t take a stand in Portland, we’ve arrested many of these leaders.
#     ('Portland', 29, 37, 'GPE', 'GPE', 'Q6106', 'Portland')
#
# -- Skipped 'right' due it's in ignore list!
#
# ++ If we didn’t take that stand right now, you would have a problem like … They were going to lose Portland.
#     ('Portland', 96, 104, 'GPE', 'GPE', 'Q6106', 'Portland')
#
#
# ++ Prosecution, sanctuary cities, incentivize illegal alien, expand asylum, abolish immigration detention.
#     ('immigration', 81, 92, 'CONCEPT', 'CONCEPT', 'Q177626', 'human migration')
#
#
# ++ The White House never sent us evidence, the Bernie, Biden platform calls for defunding or abolishing police because there is none.
#     ('The White House', 0, 15, 'ORG', 'ORG', 'Q1355327', 'Executive Office of the President of the United States')
#     ('Biden', 52, 57, 'PERSON', 'PERSON', 'Q6279', 'Joe Biden')
#
#
# ++ Joe Biden has called for redirecting some police funding for related programs like mental health counseling.
#     ('Joe Biden', 0, 9, 'PERSON', 'PERSON', 'Q6279', 'Joe Biden')
#
#
# ++ Now they want to change, 1492 Columbus discovered America.
#     ('Columbus', 30, 38, 'GPE', ['GPE', 'GPE'], ['Q16567', 'Q239870'], ['Columbus', 'Columbus'])
#     ('America', 50, 57, 'GPE', 'GPE', 'Q30', 'United States of America')
#
# -- Skipped 'right' due it's in ignore list!
#
# ++ We’re signing a healthcare plan within two weeks.
#     ('healthcare', 16, 26, 'CONCEPT', 'CONCEPT', 'Q31207', 'health care')
#
# -- Skipped 'right' due it's in ignore list!
#
# ++ A full and complete health care plan that the Supreme Court decision on DACA gave me the right to do.
#     ('health care', 20, 31, 'CONCEPT', 'CONCEPT', 'Q31207', 'health care')
#     ('Supreme Court', 46, 59, 'ORG', 'ORG', 'Q11201', 'Supreme Court of the United States')
#
#
# ++ So we’re going to solve… We’re going to sign an immigration plan, a healthcare plan and various other plans.
#     ('immigration', 48, 59, 'CONCEPT', 'CONCEPT', 'Q177626', 'human migration')
#     ('healthcare', 68, 78, 'CONCEPT', 'CONCEPT', 'Q31207', 'health care')
#
#
# ++ The Supreme Court gave the President of the United States powers that nobody thought the president had, by approving, by doing what they did, their decision on DACA.
#     ('Supreme Court', 4, 17, 'ORG', 'ORG', 'Q11201', 'Supreme Court of the United States')
#     ('the United States', 40, 57, 'GPE', 'GPE', 'Q30', 'United States of America')
#
#
# ++ But we got rid of already, which was most of Obamacare, the individual mandate.
#     ('Obamacare', 45, 54, 'ORG', 'ORG', 'Q1414593', 'Patient Protection and Affordable Care Act')
#
#
# ++ And we won also on the Supreme Court.
#     ('Supreme Court', 23, 36, 'ORG', 'ORG', 'Q11201', 'Supreme Court of the United States')
#
#
# ++ But the decision by the Supreme Court on DACA allows me to do things on immigration, on healthcare, on other things that we’ve never done before.
#     ('Supreme Court', 24, 37, 'ORG', 'ORG', 'Q11201', 'Supreme Court of the United States')
#     ('immigration', 72, 83, 'CONCEPT', 'CONCEPT', 'Q177626', 'human migration')
#     ('healthcare', 88, 98, 'CONCEPT', 'CONCEPT', 'Q31207', 'health care')
#
# -- Skipped 'executive' due it's in ignore list!
# -- Skipped 'right' due it's in ignore list!
# -- Skipped 'right' due it's in ignore list!
#
# ++ And she has in her work, helped change the course of American history.
#     ('work', 19, 23, 'CONCEPT', 'CONCEPT', 'Q192581', 'job')
#
# -- Skipped 'executive' due it's in ignore list!
# -- Skipped 'right' due it's in ignore list!
# -- Skipped 'right' due it's in ignore list!
#
# ++ With your help on Tuesday, we are going to win the Democratic primary here in California.
#     ('California', 78, 88, 'GPE', 'GPE', 'Q99', 'California')
#
#
# ++ And with your help, we are going to defeat the most dangerous President in the modern history of America.
#     ('America', 97, 104, 'GPE', 'GPE', 'Q30', 'United States of America')
#
#
# Saved 36 extracted_sentences

# %% [markdown]
# ### Test pipeline with one sentence

# %%
sentence = "POTUS 46 was born and raised in Scranton, Pennsylvania, and moved with his family to Delaware in 1953 when he was ten years old."
doc = nlp(sentence)
for ent in doc.ents:
  print(ent.text, ent.start_char, ent.end_char, ent.label_, ent._.qid, ent._.wd_name)
# Out:
# POTUS 46 0 8 PERSON Q6279 Joe Biden
# Scranton 32 40 GPE None None
# Pennsylvania 42 54 GPE None None
# Delaware 85 93 GPE None None
# 1953 97 101 DATE None None
# ten years old 114 127 DATE None None

# %% [markdown]
# ## #4. Utils (optional)

# %% [markdown]
# ### Retrieve text record from Firestore

# %%
# retrieve text record from Firestore
texts_ref = db.collection("texts")
text_doc = texts_ref.document("revcomblogtranscriptsdonaldtrumpchriswallaceinterviewtranscriptjuly19").get()
text_rec = text_doc.to_dict()

# convert timestamp to datetime string
retrieval_date = datetime.datetime.fromtimestamp(text_rec["retrieval_date"].timestamp())
text_rec["retrieval_date"] = retrieval_date.strftime("%m/%d/%Y, %H:%M:%S")

# save record in JSON file
with open(DRIVE_PATH + "/ie_course/output/text_record2.json", "w", encoding = "utf-8") as f:
  json.dump([text_rec], f, ensure_ascii = False, indent = 2)
  print(f"Saved text record")
# Out:
# Saved text record

# %% [markdown]
# ---

# %% [markdown]
# # Querying the Wikidata API

# %%
import requests

# %% [markdown]
# ## Query by keyword

# %%
label_value = "job"

query = "SELECT ?item WHERE { \
  # ?item rdfs:label '" + label_value + "'@en . \
  SERVICE wikibase:label { bd:serviceParam wikibase:language 'en'. }}"

response = requests.get("https://query.wikidata.org/sparql",
                        params={"format": "json", "query": query},
                        stream=True)
print(response)
results = response.json()
pprint(results)
# Out:
# <Response [200]>
# {'head': {'vars': ['item']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#                                     'value': 'http://www.wikidata.org/entity/Q192581'}},
#                           {'item': {'type': 'uri',
#                                     'value': 'http://www.wikidata.org/entity/Q25211948'}}]}}

# %% [markdown]
# ## Query by QID/PID

# %%
# query the Wikidata API to retrieve an entity's information
# fetch entity info from the Wikidata namespace URL

# for entity
namespace_url = f"https://www.wikidata.org/wiki/Special:EntityData/Q7322.json"
r = requests.get(namespace_url, params={"format": "json"})
# simplify access to root elements of JSON object
pprint(r.json()["entities"][f"Q7322"])

# for property
namespace_url = f"https://www.wikidata.org/wiki/Special:EntityData/P61.json"
r = requests.get(namespace_url, params={"format": "json"})
# simplify access to root elements of JSON object
pprint(r.json()["entities"][f"P61"])

# Tip: save the result into a JSON file
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                   'value': '38985'},
#                                     'hash': 'b04c50f436b9df232bfd2ca6f6e2b2b0999df5d2',
#                                     'property': 'P3762',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P3788': [{'id': 'Q7322$e666f271-4ac9-05bc-3cdd-8f1d18700878',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '000026108'},
#                                     'hash': 'c08295985554ae4f1f3e0f7de1290766df01e092',
#                                     'property': 'P3788',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P3846': [{'id': 'q7322$69926c03-4d6f-a716-0805-08b4fa4ef98e',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '87097968222206'},
#                                     'hash': 'dbc6ed8766efcbe19e5a9eb0b185b6867b85a928',
#                                     'property': 'P3846',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'references': [{'hash': 'b004bfea17467c34ce688cd26214099423775b0a',
#                                        'snaks': {'P214': [{'datatype': 'external-id',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': '17231583'},
#                                                            'hash': 'f1738d283c2c2e52f09cda5e7b33e0b619f422af',
#                                                            'property': 'P214',
#                                                            'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q54919',
#                                                                                    'numeric-id': 54919}},
#                                                            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2020-07-13T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'hash': '2aaec69065184eb6ac33aa74c3eaf601863f2500',
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P214',
#                                                        'P813']}],
#                        'type': 'statement'}],
#             'P39': [{'id': 'Q7322$9dcc73a9-475c-671d-cc3f-e712a4f68cb8',
#                      'mainsnak': {'datatype': 'wikibase-item',
#                                   'datavalue': {'type': 'wikibase-entityid',
#                                                 'value': {'entity-type': 'item',
#                                                           'id': 'Q66626376',
#                                                           'numeric-id': 66626376}},
#                                   'hash': 'dff4f850bc38dcd7061558e115d6ccf656e58eb1',
#                                   'property': 'P39',
#                                   'snaktype': 'value'},
#                      'qualifiers': {'P1366': [{'datatype': 'wikibase-item',
#                                                'datavalue': {'type': 'wikibase-entityid',
#                                                              'value': {'entity-type': 'item',
#                                                                        'id': 'Q545606',
#                                                                        'numeric-id': 545606}},
#                                                'hash': '49fc8d800fb5988b4dcfcefea8a0d70f140cd4c3',
#                                                'property': 'P1366',
#                                                'snaktype': 'value'}],
#                                     'P1534': [{'datatype': 'wikibase-item',
#                                                'datavalue': {'type': 'wikibase-entityid',
#                                                              'value': {'entity-type': 'item',
#                                                                        'id': 'Q17052147',
#                                                                        'numeric-id': 17052147}},
#                                                'hash': 'c0fdbfeb1f6a07073fec79fb05d0ec0f8df4b0b6',
#                                                'property': 'P1534',
#                                                'snaktype': 'value'}],
#                                     'P580': [{'datatype': 'time',
#                                               'datavalue': {'type': 'time',
#                                                             'value': {'after': 0,
#                                                                       'before': 0,
#                                                                       'calendarmodel': 'http://www.wikidata.org/entity/Q1985786',
#                                                                       'precision': 9,
#                                                                       'time': '+1492-00-00T00:00:00Z',
#                                                                       'timezone': 0}},
#                                               'hash': 'cc9118db96f388d5f12407ad362c617252bfe748',
#                                               'property': 'P580',
#                                               'snaktype': 'value'}],
#                                     'P582': [{'datatype': 'time',
#                                               'datavalue': {'type': 'time',
#                                                             'value': {'after': 0,
#                                                                       'before': 0,
#                                                                       'calendarmodel': 'http://www.wikidata.org/entity/Q1985786',
#                                                                       'precision': 11,
#                                                                       'time': '+1500-08-23T00:00:00Z',
#                                                                       'timezone': 0}},
#                                               'hash': 'bb4236b8d3d7619237ce709799a6c74fa8e008a9',
#                                               'property': 'P582',
#                                               'snaktype': 'value'}]},
#                      'qualifiers-order': ['P580', 'P582', 'P1366', 'P1534'],
#                      'rank': 'normal',
#                      'references': [{'hash': '0147669f02988a27916a1a526b93f29b51bd8105',
#                                      'snaks': {'P854': [{'datatype': 'url',
#                                                          'datavalue': {'type': 'string',
#                                                                        'value': 'https://www.newworldencyclopedia.org/entry/Christopher_Columbus'},
#                                                          'hash': 'e69ed371b7162bd740fc9565863ee566e589b472',
#                                                          'property': 'P854',
#                                                          'snaktype': 'value'}]},
#                                      'snaks-order': ['P854']}],
#                      'type': 'statement'},
#                     {'id': 'Q7322$55b4f4c0-47dd-526c-458f-9e057dae0ce6',
#                      'mainsnak': {'datatype': 'wikibase-item',
#                                   'datavalue': {'type': 'wikibase-entityid',
#                                                 'value': {'entity-type': 'item',
#                                                           'id': 'Q77380502',
#                                                           'numeric-id': 77380502}},
#                                   'hash': '914110aabb3cfeefb5d313fc9e0e6b7461f46bf5',
#                                   'property': 'P39',
#                                   'snaktype': 'value'},
#                      'qualifiers': {'P1534': [{'datatype': 'wikibase-item',
#                                                'datavalue': {'type': 'wikibase-entityid',
#                                                              'value': {'entity-type': 'item',
#                                                                        'id': 'Q5247364',
#                                                                        'numeric-id': 5247364}},
#                                                'hash': 'b88861d4e94bc318c54070de73a33cbac499ea1f',
#                                                'property': 'P1534',
#                                                'snaktype': 'value'}],
#                                     'P580': [{'datatype': 'time',
#                                               'datavalue': {'type': 'time',
#                                                             'value': {'after': 0,
#                                                                       'before': 0,
#                                                                       'calendarmodel': 'http://www.wikidata.org/entity/Q1985786',
#                                                                       'precision': 11,
#                                                                       'time': '+1492-04-17T00:00:00Z',
#                                                                       'timezone': 0}},
#                                               'hash': 'ae523ac7370b2d2446934e30e71f8a355e328761',
#                                               'property': 'P580',
#                                               'snaktype': 'value'}],
#                                     'P582': [{'datatype': 'time',
#                                               'datavalue': {'type': 'time',
#                                                             'value': {'after': 0,
#                                                                       'before': 0,
#                                                                       'calendarmodel': 'http://www.wikidata.org/entity/Q1985786',
#                                                                       'precision': 11,
#                                                                       'time': '+1506-05-20T00:00:00Z',
#                                                                       'timezone': 0}},
#                                               'hash': 'd21049a418b04d68b849de5536b9653f379fa507',
#                                               'property': 'P582',
#                                               'snaktype': 'value'}]},
#                      'qualifiers-order': ['P580', 'P582', 'P1534'],
#                      'rank': 'normal',
#                      'type': 'statement'}],
#             'P396': [{'id': 'Q7322$928A89F2-DAF2-4F4F-BBBF-1FADFF2D7BF1',
#                       'mainsnak': {'datatype': 'external-id',
#                                    'datavalue': {'type': 'string',
#                                                  'value': 'CFIV007642'},
#                                    'hash': '7b5020a8c69d92288f84866891d27c48ae54b285',
#                                    'property': 'P396',
#                                    'snaktype': 'value'},
#                       'qualifiers': {'P1810': [{'datatype': 'string',
#                                                 'datavalue': {'type': 'string',
#                                                               'value': 'Colombo, '
#                                                                        'Cristoforo '
#                                                                        '<1451-1506>'},
#                                                 'hash': 'f84f68f21b39888d818981467e5b87d9d8d58f85',
#                                                 'property': 'P1810',
#                                                 'snaktype': 'value'}]},
#                       'qualifiers-order': ['P1810'],
#                       'rank': 'normal',
#                       'type': 'statement'}],
#             'P3964': [{'id': 'Q7322$0fbf2d71-44c8-ee67-3197-32eccb3901f1',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '8666'},
#                                     'hash': 'd7402c2c9a369016ad2271a77339e7751265654c',
#                                     'property': 'P3964',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P3987': [{'id': 'Q7322$999592FC-40FC-44FE-A8EC-792A99966E23',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '75511'},
#                                     'hash': '3dbc394dd5da443ba25e91ee9282eaebd8e42d46',
#                                     'property': 'P3987',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P40': [{'id': 'Q7322$7242DE24-476E-4BBB-88EF-BA35F6B7309D',
#                      'mainsnak': {'datatype': 'wikibase-item',
#                                   'datavalue': {'type': 'wikibase-entityid',
#                                                 'value': {'entity-type': 'item',
#                                                           'id': 'Q1406718',
#                                                           'numeric-id': 1406718}},
#                                   'hash': 'ebbed750578aa11c53984eedbdee8e4b5376d3a7',
#                                   'property': 'P40',
#                                   'snaktype': 'value'},
#                      'rank': 'normal',
#                      'type': 'statement'},
#                     {'id': 'Q7322$F4D11CEC-D3D9-4FA7-8B3A-C0A10834BAE6',
#                      'mainsnak': {'datatype': 'wikibase-item',
#                                   'datavalue': {'type': 'wikibase-entityid',
#                                                 'value': {'entity-type': 'item',
#                                                           'id': 'Q452379',
#                                                           'numeric-id': 452379}},
#                                   'hash': 'f3cd2bbc875ce73ce4e7bda167b4af34bc2d68a3',
#                                   'property': 'P40',
#                                   'snaktype': 'value'},
#                      'rank': 'normal',
#                      'references': [{'hash': '56296c22fda8ff0509f71ed7cc067bcbe11856ac',
#                                      'snaks': {'P248': [{'datatype': 'wikibase-item',
#                                                          'datavalue': {'type': 'wikibase-entityid',
#                                                                        'value': {'entity-type': 'item',
#                                                                                  'id': 'Q19847326',
#                                                                                  'numeric-id': 19847326}},
#                                                          'hash': '18a7eccf050ab7390888344c498336e62366cbdb',
#                                                          'property': 'P248',
#                                                          'snaktype': 'value'}]},
#                                      'snaks-order': ['P248']}],
#                      'type': 'statement'}],
#             'P4081': [{'id': 'Q7322$1C570044-1FAF-4952-8820-8595F1F65163',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '11787'},
#                                     'hash': '9a48839c06af500445d689ac235fe8aafec6e236',
#                                     'property': 'P4081',
#                                     'snaktype': 'value'},
#                        'qualifiers': {'P1810': [{'datatype': 'string',
#                                                  'datavalue': {'type': 'string',
#                                                                'value': 'Columbus, '
#                                                                         'Christopher.'},
#                                                  'hash': '7bdefedede45552cd2659b2d566a3a2e6672e9e3',
#                                                  'property': 'P1810',
#                                                  'snaktype': 'value'}]},
#                        'qualifiers-order': ['P1810'],
#                        'rank': 'normal',
#                        'references': [{'hash': '2b6006b148910f6023cfd5e1b2243035954621cd',
#                                        'snaks': {'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2018-06-02T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'hash': 'a39f1f5e2ec1a303279f454587d0adc4f3c76ee2',
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P813']}],
#                        'type': 'statement'}],
#             'P409': [{'id': 'Q7322$1BC6F115-CF9D-45EF-9628-A07C4D08319A',
#                       'mainsnak': {'datatype': 'external-id',
#                                    'datavalue': {'type': 'string',
#                                                  'value': '35784235'},
#                                    'hash': '29d8d568dc9ed4d10ebaf2d3f8be9b76d6d5545e',
#                                    'property': 'P409',
#                                    'snaktype': 'value'},
#                       'rank': 'normal',
#                       'type': 'statement'}],
#             'P410': [{'id': 'Q7322$16C082D7-EDC7-4B15-A93F-F5127123EBDA',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q132851',
#                                                            'numeric-id': 132851}},
#                                    'hash': 'df7c804285690602bd97754f3655c944fe8849e2',
#                                    'property': 'P410',
#                                    'snaktype': 'value'},
#                       'rank': 'normal',
#                       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#                                       'snaks': {'P143': [{'datatype': 'wikibase-item',
#                                                           'datavalue': {'type': 'wikibase-entityid',
#                                                                         'value': {'entity-type': 'item',
#                                                                                   'id': 'Q328',
#                                                                                   'numeric-id': 328}},
#                                                           'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#                                                           'property': 'P143',
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P143']}],
#                       'type': 'statement'},
#                      {'id': 'Q7322$7bb7664c-4428-915c-f006-f77297d2660b',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q16145664',
#                                                            'numeric-id': 16145664}},
#                                    'hash': '0c7b34df5057e4e5c6147e81e539220463a7b5d1',
#                                    'property': 'P410',
#                                    'snaktype': 'value'},
#                       'qualifiers': {'P1545': [{'datatype': 'string',
#                                                 'datavalue': {'type': 'string',
#                                                               'value': '1'},
#                                                 'hash': '2a1ced1dca90648ea7e306acbadd74fc81a10722',
#                                                 'property': 'P1545',
#                                                 'snaktype': 'value'}],
#                                      'P580': [{'datatype': 'time',
#                                                'datavalue': {'type': 'time',
#                                                              'value': {'after': 0,
#                                                                        'before': 0,
#                                                                        'calendarmodel': 'http://www.wikidata.org/entity/Q1985786',
#                                                                        'precision': 9,
#                                                                        'time': '+1492-00-00T00:00:00Z',
#                                                                        'timezone': 0}},
#                                                'hash': 'cc9118db96f388d5f12407ad362c617252bfe748',
#                                                'property': 'P580',
#                                                'snaktype': 'value'}]},
#                       'qualifiers-order': ['P580', 'P1545'],
#                       'rank': 'normal',
#                       'type': 'statement'}],
#             'P4159': [{'id': 'Q7322$581288BB-15FF-4735-99DC-A053F8D21E16',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'Christopher_Columbus_(1)'},
#                                     'hash': '0b8d20fbeacb14c3a00956784d968b077c715535',
#                                     'property': 'P4159',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P4223': [{'id': 'Q7322$b0fcfde5-4126-7067-4b9b-2b5b8cd7a7a6',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'cristoforo-colombo'},
#                                     'hash': 'f19a17f4e76daa59824058c5f3cb2a6e0172dd75',
#                                     'property': 'P4223',
#                                     'snaktype': 'value'},
#                        'qualifiers': {'P1810': [{'datatype': 'string',
#                                                  'datavalue': {'type': 'string',
#                                                                'value': 'COLOMBO, '
#                                                                         'Cristoforo'},
#                                                  'hash': 'c3f12bed28a0d809dd5e9a063962bfd1105da92a',
#                                                  'property': 'P1810',
#                                                  'snaktype': 'value'}],
#                                       'P2093': [{'datatype': 'string',
#                                                  'datavalue': {'type': 'string',
#                                                                'value': 'Alberto '
#                                                                         'Magnaghi'},
#                                                  'hash': 'd47eabdd5e4eac0f954b1bd069f9e00124a27df5',
#                                                  'property': 'P2093',
#                                                  'snaktype': 'value'},
#                                                 {'datatype': 'string',
#                                                  'datavalue': {'type': 'string',
#                                                                'value': 'Eugenio '
#                                                                         'Mele '
#                                                                         '-'},
#                                                  'hash': '8b7cc7a48fc563dfe80a9b91fbf8c3f2a21dc0f1',
#                                                  'property': 'P2093',
#                                                  'snaktype': 'value'}],
#                                       'P577': [{'datatype': 'time',
#                                                 'datavalue': {'type': 'time',
#                                                               'value': {'after': 0,
#                                                                         'before': 0,
#                                                                         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                         'precision': 9,
#                                                                         'time': '+1931-01-01T00:00:00Z',
#                                                                         'timezone': 0}},
#                                                 'hash': '9947bfc175b6a64ec849b93f7c5a138bbccd77e1',
#                                                 'property': 'P577',
#                                                 'snaktype': 'value'}]},
#                        'qualifiers-order': ['P1810', 'P2093', 'P577'],
#                        'rank': 'normal',
#                        'references': [{'hash': '43858d6ad06a5f3b1f87e4ee6765641f5c97f36b',
#                                        'snaks': {'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q731361',
#                                                                                    'numeric-id': 731361}},
#                                                            'hash': '34eeda6017137fe962f181714ee5f1ed649a7cc6',
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2022-05-28T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'hash': 'dc7229f489e3fa9df7411c753de4d15089dfd6b8',
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248', 'P813']}],
#                        'type': 'statement'}],
#             'P4293': [{'id': 'Q7322$5B6F4E41-EF32-4861-964B-7627AB16A8AE',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'pe/003403'},
#                                     'hash': 'e8631ed31ddb98b398898b665693ee9e19b045af',
#                                     'property': 'P4293',
#                                     'snaktype': 'value'},
#                        'qualifiers': {'P1810': [{'datatype': 'string',
#                                                  'datavalue': {'type': 'string',
#                                                                'value': 'Colombo, '
#                                                                         'Cristoforo'},
#                                                  'hash': 'e4b4cc4c7f37f2b9d9e1844c28c2424ee009bed8',
#                                                  'property': 'P1810',
#                                                  'snaktype': 'value'}],
#                                       'P3740': [{'datatype': 'quantity',
#                                                  'datavalue': {'type': 'quantity',
#                                                                'value': {'amount': '+29',
#                                                                          'unit': '1'}},
#                                                  'hash': '0f0207055e326857d4fce5a23bc763a33e12ee62',
#                                                  'property': 'P3740',
#                                                  'snaktype': 'value'}],
#                                       'P5592': [{'datatype': 'quantity',
#                                                  'datavalue': {'type': 'quantity',
#                                                                'value': {'amount': '+22',
#                                                                          'unit': '1'}},
#                                                  'hash': '1f08b74dbb10082162a4fd94a4bbca25dec1b546',
#                                                  'property': 'P5592',
#                                                  'snaktype': 'value'}]},
#                        'qualifiers-order': ['P3740', 'P5592', 'P1810'],
#                        'rank': 'normal',
#                        'references': [{'hash': '20f19263a9f6b33e773ac2ee2ad054ffd0fd22d7',
#                                        'snaks': {'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2017-10-23T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'hash': '698b9527b9d351eb03c2cf2d6610785c9280665b',
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}],
#                                                  'P854': [{'datatype': 'url',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': 'http://purl.org/pressemappe20/beaconlist/pe'},
#                                                            'hash': '7c6cfd8f67afe2f78cf3ff5e4bcc139ebec47a76',
#                                                            'property': 'P854',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P854', 'P813']}],
#                        'type': 'statement'}],
#             'P4342': [{'id': 'Q7322$514328ED-128E-4187-967B-8F5F7A6AE10B',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'Kristoffer_Columbus'},
#                                     'hash': '44f409e8a663c387fc600c3ea483af8709ed63d5',
#                                     'property': 'P4342',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P4359': [{'id': 'Q7322$A61FC9BC-78AC-4B2A-87DD-CA48CD373A64',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'christophercolumbus'},
#                                     'hash': 'e3f12d3bedb07f351fb90999031778a6aa065631',
#                                     'property': 'P4359',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P4459': [{'id': 'Q7322$13110AE2-33B5-4094-ABB3-B964BDA06885',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '4665/cristobal-colon'},
#                                     'hash': '7f657cc87c932e57121f83ccd6292815a3afe52f',
#                                     'property': 'P4459',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P451': [{'id': 'Q7322$4320B91B-EA99-4292-BBD4-887D1CEEBB4B',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q463646',
#                                                            'numeric-id': 463646}},
#                                    'hash': '1d6949c4ea1ba6bb2b8e3dc13e305fcf6713fd03',
#                                    'property': 'P451',
#                                    'snaktype': 'value'},
#                       'rank': 'normal',
#                       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#                                       'snaks': {'P143': [{'datatype': 'wikibase-item',
#                                                           'datavalue': {'type': 'wikibase-entityid',
#                                                                         'value': {'entity-type': 'item',
#                                                                                   'id': 'Q328',
#                                                                                   'numeric-id': 328}},
#                                                           'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#                                                           'property': 'P143',
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P143']}],
#                       'type': 'statement'}],
#             'P4539': [{'id': 'Q7322$A2668B35-F4F3-466C-B8DB-9849AAF5A52A',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '15737'},
#                                     'hash': '0b3cdd8e3464752cbf37168afabeb2b400bbc675',
#                                     'property': 'P4539',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P4619': [{'id': 'q7322$9d3b7a26-46f8-3160-532b-b9c1922c4409',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '000157373'},
#                                     'hash': '026838a07f95c2fb4bf2de04d0fea78a632d25c8',
#                                     'property': 'P4619',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'references': [{'hash': 'b004bfea17467c34ce688cd26214099423775b0a',
#                                        'snaks': {'P214': [{'datatype': 'external-id',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': '17231583'},
#                                                            'hash': 'f1738d283c2c2e52f09cda5e7b33e0b619f422af',
#                                                            'property': 'P214',
#                                                            'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q54919',
#                                                                                    'numeric-id': 54919}},
#                                                            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2020-07-13T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'hash': '2aaec69065184eb6ac33aa74c3eaf601863f2500',
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P214',
#                                                        'P813']}],
#                        'type': 'statement'}],
#             'P4629': [{'id': 'Q7322$3024A5E3-037F-490B-92BB-ECD39E51CA65',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'Columbus, '
#                                                            'Christopher'},
#                                     'hash': 'c3613fbd13d450f1f71db3427f7c066c83e2951d',
#                                     'property': 'P4629',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P463': [{'id': 'Q7322$adbd54fd-46ce-f5a6-db67-ccf7df4eef7a',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q66823411',
#                                                            'numeric-id': 66823411}},
#                                    'hash': '4628e4f1eb30a7daf9512c9f5a902bfdabfa9849',
#                                    'property': 'P463',
#                                    'snaktype': 'value'},
#                       'rank': 'normal',
#                       'type': 'statement'}],
#             'P4823': [{'id': 'Q7322$68928146-EC6D-4017-BD90-F79447CB3B05',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '2000200'},
#                                     'hash': '58d3c7bc3919fa28407578786ab9a0479af6f808',
#                                     'property': 'P4823',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P4839': [{'id': 'Q7322$EE64AA43-2B56-441D-91E0-889EE73CE1D7',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'Entity["Concept", '
#                                                            '"ChristopherColumbus::4r362"]'},
#                                     'hash': '4b2e7718684900faf2309b762be8d706453e6b7d',
#                                     'property': 'P4839',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P5002': [{'id': 'Q7322$4fdd81bb-413b-db3e-c28a-6588bb5069eb',
#                        'mainsnak': {'datatype': 'external-id',
#                                     'datavalue': {'type': 'string',
#                                                   'value': '1841804'},
#                                     'hash': 'e85300090fb1ed56dbd09498591754f8ef849503',
#                                     'property': 'P5002',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'}],
#             'P5008': [{'id': 'Q7322$108E183B-1093-4845-B230-D090C3137D2C',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q5460604',
#                                                             'numeric-id': 5460604}},
#                                     'hash': 'd8037e40c3d12c404489a97a78937213939ff1cd',
#                                     'property': 'P5008',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'},
#                       {'id': 'Q7322$e866c9d3-43d4-041b-77d9-a717f18d3cca',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q103505599',
#                                                             'numeric-id': 103505599}},
#                                     'hash': '8cfab72fde6b6e32be3902543c9510ade973a68b',
#                                     'property': 'P5008',
#                                     'snaktype': 'value'},
#                        'rank': 'normal',
#                        'type': 'statement'},
#                       {'id': 'Q7322$965D80E1-C274-4049-8297-FCC8729C06EB',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q6173448',
#                                                             'numeric-id': 6173448}},
#                                     'hash': '136e3fbe19158e73e4bfebf3f2d98a9df8638b7e',
#                                     'property': 'P5008',
#                                     'snaktype': 'value'},
#                        'qualifiers': {'P585': [{'datatype': 'time',
#                                                 'datavalue': {'type': 'time',
#                                                               'value': {'after': 0,
#                                                                         'before': 0,
#                                                                         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                         'precision': 11,
#                                                                         'time': '+2022-10-31T00:00:00Z',
#                                                                         'timezone': 0}},
#                                                 'hash': '7661f66dd5b82a1ea92515ddb16c09ce3088edea',
#                                                 'property': 'P585',
#                                                 'snaktype': 'value'}]},
#                        'qualifiers-order': ['P585'],
#                        'rank': 'normal',
#                        'type': 'statement'}],
# ...
#                          'value': 'bet dizoloet pe ijinet gant'},
#                   'bs': {'language': 'bs', 'value': 'otkrio ili izumio'},
#                   'ca': {'language': 'ca', 'value': 'descobert o inventat per'},
#                   'cs': {'language': 'cs',
#                          'value': 'člověk, který položku objevil, poprvé '
#                                   'popsal nebo vynalezl'},
#                   'da': {'language': 'da',
#                          'value': 'opdaget eller opfundet af'},
#                   'de': {'language': 'de',
#                          'value': 'Entdecker, Erfinder oder Entwickler dieser '
#                                   'Entdeckung oder Erfindung'},
#                   'en': {'language': 'en',
#                          'value': 'subject who discovered, first described, '
#                                   'invented, or developed this discovery or '
#                                   'invention'},
#                   'en-ca': {'language': 'en-ca',
#                             'value': 'discovered, first described, or invented '
#                                      'by'},
#                   'en-gb': {'language': 'en-gb',
#                             'value': 'discovered, first described, or invented '
#                                      'by'},
#                   'es': {'language': 'es',
#                          'value': 'descubierto o inventado por'},
#                   'eu': {'language': 'eu',
#                          'value': 'Elementuaren aurkitzailea edo asmatzailea'},
#                   'fa': {'language': 'fa', 'value': 'کشف\u200cشده توسط'},
#                   'fi': {'language': 'fi',
#                          'value': 'henkilö, joka on löytänyt tai keksinyt '
#                                   'kohteen'},
#                   'fr': {'language': 'fr',
#                          'value': 'personne qui a découvert ou inventé '
#                                   "l'élément"},
#                   'frr': {'language': 'frr',
#                           'value': 'persuun, diar wat (ütj)fünjen hää'},
#                   'gl': {'language': 'gl',
#                          'value': 'descuberto, descrito por primeira vez ou '
#                                   'inventado por'},
#                   'gpe': {'language': 'gpe',
#                           'value': 'subject wey dem discover, dem describe am '
#                                    'first, dem invent am, or dem develop dis '
#                                    'discovery or invention'},
#                   'gu': {'language': 'gu',
#                          'value': 'દ્વારા શોધાયેલ અથવા સંશોધાયેલ'},
#                   'he': {'language': 'he',
#                          'value': 'האדם שגילה את המקום או את הגרם השמיימי'},
#                   'hi': {'language': 'hi',
#                          'value': 'वह इकाई जिसने पहली बार इस खोज या आविष्कार '
#                                   'का पता लगाया, उसका आविष्कार किया या उसका '
#                                   'विकास किया'},
#                   'hr': {'language': 'hr',
#                          'value': 'tko je otkrio ovaj subjekt'},
#                   'hsb': {'language': 'hsb',
#                           'value': 'wosoba, kotraž je objekt wotkryła abo '
#                                    'wunamakała'},
#                   'id': {'language': 'id',
#                          'value': 'ditemukan atau diciptakan oleh'},
#                   'ig': {'language': 'ig',
#                          'value': 'onye chọpụtara,onye mbụ kpọpụtara,onye '
#                                   'wepụtara ma ọ mụtara ma ọ mepere nchọpụta '
#                                   'a'},
#                   'ilo': {'language': 'ilo',
#                           'value': 'sino ti nakaduktal wenno nakainbento'},
#                   'it': {'language': 'it',
#                          'value': 'persona o gruppo che ha/hanno scoperto o '
#                                   "inventato l'elemento"},
#                   'ja': {'language': 'ja', 'value': 'その項目を発見または発明した人物や団体'},
#                   'kcg': {'language': 'kcg',
#                           'value': 'a̱tyu a̱ ku tsa ta̱taat, bwuo, mat, nyia̱, '
#                                    'nok ku wa̱i kyang a̱ni'},
#                   'ko': {'language': 'ko', 'value': '항목 주제를 처음으로 발견·발명한 대상'},
#                   'min': {'language': 'min',
#                           'value': 'manamuan sasuatu nan bamanfaaik'},
#                   'ms': {'language': 'ms',
#                          'value': 'tertemu, pertama kali diterang, atau direka '
#                                   'oleh'},
#                   'nb': {'language': 'nb',
#                          'value': 'oppdaget eller oppfunnet av'},
#                   'nl': {'language': 'nl',
#                          'value': 'naam van ontdekker of uitvinder'},
#                   'nqo': {'language': 'nqo',
#                           'value': 'ߡߍ߲ ߞߊ߬ ߝߋ߲ ߞߎ߲߬ߠߊߞߊ߬߸ ߛߓߍߦߊߓߊ߮ ߝߟߐ߸ '
#                                    'ߛߌ߲ߘߌߓߊ߮߸ ߥߟߊ߫ ߞߊ߬ ߞߎ߲߬ߠߞߊ߬ߟߌ ߏ߬ ߟߊߛߓߊ߬ߕߌ߬ '
#                                    'ߥߟߊ߫ ߛߌ߲ߘߟߌ'},
#                   'oc': {'language': 'oc', 'value': 'descobèrt o inventat per'},
#                   'pl': {'language': 'pl',
#                          'value': 'osoba, która odkryła, po raz pierwszy '
#                                   'opisała, wynalazła lub opracowała to '
#                                   'odkrycie lub wynalazek'},
#                   'pt': {'language': 'pt',
#                          'value': 'entidade que descobriu, inventou ou '
#                                   'descrever o objecto pela primeira vez'},
#                   'pt-br': {'language': 'pt-br',
#                             'value': 'objeto foi descoberto ou inventado por'},
#                   'ro': {'language': 'ro',
#                          'value': 'persoana sau echipa care a descoperit sau '
#                                   'inventat elementul'},
#                   'ru': {'language': 'ru',
#                          'value': 'кем открыт или изобретён этот элемент'},
#                   'scn': {'language': 'scn',
#                           'value': 'cu scuprìu o nvintau lu suggettu'},
#                   'sr': {'language': 'sr', 'value': 'открио или изумео'},
#                   'sr-ec': {'language': 'sr-ec', 'value': 'открио или изумео'},
#                   'sr-el': {'language': 'sr-el', 'value': 'otkrio ili izumeo'},
#                   'sv': {'language': 'sv', 'value': 'upptäckt av'},
#                   'sw': {'language': 'sw',
#                          'value': 'mtu ambaye aligundua, alielezea kwanza, '
#                                   'alievumbua, au kuendeleza ugunduzi au '
#                                   'uvumbuzi huu'},
#                   'tr': {'language': 'tr',
#                          'value': 'keşfeden, ilk tanımlayan veya icat eden'},
#                   'uk': {'language': 'uk',
#                          'value': "ким відкрито або винайдено цей об'єкт"},
#                   'yue': {'language': 'yue', 'value': '第一個發現或者發明呢樣嘢嘅人'},
#                   'zh': {'language': 'zh', 'value': '发现、首先描述、发明或开发此发现或发明的主体'},
#                   'zh-cn': {'language': 'zh-cn', 'value': '首次发现或发明此项的人'},
#                   'zh-hans': {'language': 'zh-hans', 'value': '首次发现或发明此项的人'},
#                   'zh-hant': {'language': 'zh-hant', 'value': '首次發現或發明此項的人'},
#                   'zh-hk': {'language': 'zh-hk', 'value': '首次發現或發明此項的人'},
#                   'zh-mo': {'language': 'zh-mo', 'value': '首次發現或發明此項的人'},
#                   'zh-my': {'language': 'zh-my', 'value': '首次发现或发明此项的人'},
#                   'zh-sg': {'language': 'zh-sg', 'value': '首次发现或发明此项的人'},
#                   'zh-tw': {'language': 'zh-tw', 'value': '首次發現或發明此項的人'}},
#  'id': 'P61',
#  'labels': {'af': {'language': 'af', 'value': 'Ontdek deur'},
#             'ar': {'language': 'ar', 'value': 'المكتشف أو المخترع'},
#             'ast': {'language': 'ast', 'value': 'descubridor o inventor'},
#             'az': {'language': 'az', 'value': 'ixtiraçı və ya kəşf edən'},
#             'ba': {'language': 'ba', 'value': 'асыусы йәки уйлап табыусы'},
#             'be': {'language': 'be', 'value': 'першаадкрывальнік'},
#             'be-tarask': {'language': 'be-tarask',
#                           'value': 'першаадкрывальнік'},
#             'bg': {'language': 'bg', 'value': 'откривател или изобретател'},
#             'bn': {'language': 'bn', 'value': 'আবিষ্কারক বা উদ্ভাবক'},
#             'br': {'language': 'br', 'value': 'dizoloer pe ijiner'},
#             'bs': {'language': 'bs', 'value': 'otkrivač ili izumitelj'},
#             'ca': {'language': 'ca', 'value': 'descobridor o inventor'},
#             'ce': {'language': 'ce', 'value': 'юьхь йиллинарг я кхоллархо'},
#             'crh': {'language': 'crh', 'value': 'kâşifi yaki mucidi'},
#             'cs': {'language': 'cs', 'value': 'objevitel nebo vynálezce'},
#             'cy': {'language': 'cy', 'value': 'darganfyddwr neu ddyfeisiwr'},
#             'da': {'language': 'da', 'value': 'opdager eller opfinder'},
#             'de': {'language': 'de', 'value': 'Entdecker oder Erfinder'},
#             'diq': {'language': 'diq', 'value': 'Keşıfkar ya na Mucid'},
#             'el': {'language': 'el', 'value': 'ανακαλύφθηκε ή εφευρέθηκε από'},
#             'en': {'language': 'en', 'value': 'discoverer or inventor'},
#             'en-ca': {'language': 'en-ca', 'value': 'discoverer or inventor'},
#             'en-gb': {'language': 'en-gb', 'value': 'discoverer or inventor'},
#             'eo': {'language': 'eo', 'value': 'malkovrinto aŭ inventinto'},
#             'es': {'language': 'es', 'value': 'descubridor o inventor'},
#             'et': {'language': 'et', 'value': 'leiutaja või avastaja'},
#             'eu': {'language': 'eu', 'value': 'aurkitzailea edo asmatzailea'},
#             'fa': {'language': 'fa', 'value': 'کاشف'},
#             'fi': {'language': 'fi', 'value': 'löytäjä tai keksijä'},
#             'fr': {'language': 'fr', 'value': 'découvert(e) ou inventé(e) par'},
#             'frr': {'language': 'frr', 'value': 'ütjfinjer'},
#             'ga': {'language': 'ga', 'value': 'fionnachtaí nó aireagóir'},
#             'gl': {'language': 'gl', 'value': 'descubridor ou inventor'},
#             'gpe': {'language': 'gpe', 'value': 'discoverer or inventor'},
#             'gu': {'language': 'gu', 'value': 'શોધક અથવા સંશોધક'},
#             'ha': {'language': 'ha', 'value': 'mai ganowa ko mai ƙirƙira'},
#             'he': {'language': 'he', 'value': 'מגלה או ממציא'},
#             'hi': {'language': 'hi', 'value': 'खोजकर्ता या आविष्कारक'},
#             'hr': {'language': 'hr', 'value': 'otkrio/izumio'},
#             'hsb': {'language': 'hsb', 'value': 'wotkrywar abo wunamakar'},
#             'hu': {'language': 'hu', 'value': 'felfedező vagy feltaláló'},
#             'hy': {'language': 'hy', 'value': 'հայտնաբերող կամ հնարող'},
#             'ia': {'language': 'ia', 'value': 'discoperitor o inventor'},
#             'id': {'language': 'id', 'value': 'penemu atau pencipta'},
#             'ig': {'language': 'ig', 'value': 'onye nchọpụta'},
#             'ilo': {'language': 'ilo', 'value': 'nakaduktal wenno inbentor'},
#             'io': {'language': 'io', 'value': 'deskovrinto od inventinto'},
#             'is': {'language': 'is', 'value': 'uppgvötuð af'},
#             'it': {'language': 'it', 'value': 'scoperto o inventato da'},
#             'ja': {'language': 'ja', 'value': '発見者または発明者'},
#             'ka': {'language': 'ka', 'value': 'აღმომჩენი'},
#             'kcg': {'language': 'kcg', 'value': 'a̱tyuya̱taat ku a̱tyubwoi'},
#             'ko': {'language': 'ko', 'value': '다음이 발견·발명하였음'},
#             'ks': {'language': 'ks', 'value': 'دٕریافَت کار'},
#             'ku': {'language': 'ku', 'value': 'kaşîf an îcadker'},
#             'kw': {'language': 'kw', 'value': 'diskudher po dismyger'},
#             'la': {'language': 'la', 'value': 'inventor'},
#             'lb': {'language': 'lb', 'value': 'Entdecker oder Erfinder'},
#             'lt': {'language': 'lt', 'value': 'atradėjas arba išradėjas'},
#             'lv': {'language': 'lv', 'value': 'atklājējs vai izgudrotājs'},
#             'min': {'language': 'min', 'value': 'panamu'},
#             'mk': {'language': 'mk', 'value': 'откривач'},
#             'ml': {'language': 'ml', 'value': 'കണ്ടുപിടിച്ചയാൾ'},
#             'mr': {'language': 'mr', 'value': 'अनावरक (डिस्कव्हरर) किंवा शोधक'},
#             'ms': {'language': 'ms', 'value': 'penemu atau pereka'},
#             'ms-arab': {'language': 'ms-arab', 'value': 'ڤنمو اتاو ڤريک'},
#             'my': {'language': 'my',
#                    'value': 'ရှာဖွေတွေ့ရှိသူ (သို့) တီထွင်သူ'},
#             'nap': {'language': 'nap', 'value': 'scuperto o inventato da'},
#             'nb': {'language': 'nb', 'value': 'oppdager eller oppfinner'},
#             'nds': {'language': 'nds', 'value': 'Opdecker'},
#             'nl': {'language': 'nl', 'value': 'ontdekker of uitvinder'},
#             'nn': {'language': 'nn', 'value': 'oppdagar eller oppfinnar'},
#             'nqo': {'language': 'nqo', 'value': 'ߞߎ߲߬ߠߊ߬ߞߊ߬ߓߊ߮ ߥߟߊ߫ ߛߌ߲ߘߌߓߊ߮'},
#             'oc': {'language': 'oc', 'value': 'descobridor o inventaire'},
#             'or': {'language': 'or', 'value': 'ଆବିଷ୍କାରକ ବା ଉଦ୍ଭାବକ'},
#             'pa': {'language': 'pa', 'value': 'ਖੋਜੀ ਜਾਂ ਕਾਢੀ'},
#             'pap': {'language': 'pap', 'value': 'deskubridó òf inventor'},
#             'pl': {'language': 'pl', 'value': 'odkrywca lub wynalazca'},
#             'pt': {'language': 'pt', 'value': 'descobridor ou inventor'},
#             'pt-br': {'language': 'pt-br',
#                       'value': 'descoberto ou inventado por'},
#             'ro': {'language': 'ro', 'value': 'descoperit(ă) de'},
#             'ru': {'language': 'ru',
#                    'value': 'первооткрыватель или изобретатель'},
#             'scn': {'language': 'scn', 'value': 'scuprituri o invinturi'},
#             'sco': {'language': 'sco', 'value': 'discoverer or inventor'},
#             'se': {'language': 'se', 'value': 'gávdni dahje hutki'},
#             'sk': {'language': 'sk', 'value': 'objaviteľ alebo vynálezca'},
#             'sl': {'language': 'sl', 'value': 'odkritelj ali izumitelj'},
#             'smn': {'language': 'smn', 'value': 'kävnee teikkâ utkee'},
#             'sms': {'language': 'sms', 'value': 'kaunni leʹbe hoʹhssjeei'},
#             'sq': {'language': 'sq', 'value': 'zbulues'},
#             'sr': {'language': 'sr', 'value': 'открио'},
#             'sr-ec': {'language': 'sr-ec', 'value': 'открио'},
#             'sr-el': {'language': 'sr-el', 'value': 'otkrio'},
#             'sv': {'language': 'sv', 'value': 'upptäckare eller uppfinnare'},
#             'sw': {'language': 'sw', 'value': 'mgunduzi au mvumbuzi'},
#             'ta': {'language': 'ta', 'value': 'கண்டுபிடிப்பாளர்'},
#             'te': {'language': 'te', 'value': 'కనుగొన్నవారు'},
#             'tg': {'language': 'tg', 'value': 'кошиф'},
#             'th': {'language': 'th', 'value': 'ผู้ค้นพบ/ผู้ประดิษฐ์'},
#             'tr': {'language': 'tr', 'value': 'kâşifi ya da mucidi'},
#             'tt': {'language': 'tt', 'value': 'ачучы яки уйлап табучы'},
#             'uk': {'language': 'uk', 'value': 'першовідкривач або винахідник'},
#             'ur': {'language': 'ur', 'value': 'دریافت کنندہ'},
#             'vec': {'language': 'vec', 'value': 'descuerzidor o inventor'},
#             'vi': {'language': 'vi', 'value': 'được phát hiện bởi'},
#             'yue': {'language': 'yue', 'value': '發現人或發明人'},
#             'zh': {'language': 'zh', 'value': '發現者或發明者'},
#             'zh-cn': {'language': 'zh-cn', 'value': '发现者或发明者'},
#             'zh-hans': {'language': 'zh-hans', 'value': '发现者或发明者'},
#             'zh-hant': {'language': 'zh-hant', 'value': '發現者或發明者'},
#             'zh-hk': {'language': 'zh-hk', 'value': '發現者或發明者'},
#             'zh-mo': {'language': 'zh-mo', 'value': '發現者或發明者'},
#             'zh-my': {'language': 'zh-my', 'value': '发现者或发明者'},
#             'zh-sg': {'language': 'zh-sg', 'value': '发现者或发明者'},
#             'zh-tw': {'language': 'zh-tw', 'value': '發現者或發明者'}},
#  'lastrevid': 1783673925,
#  'modified': '2022-12-03T21:58:48Z',
#  'ns': 120,
#  'pageid': 3924868,
#  'title': 'Property:P61',
#  'type': 'property'}
